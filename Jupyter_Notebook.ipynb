# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# __Rina Putri Sari__<br>
# __Data Scientist__

# %% [markdown]
# _I am interested in data science because it is a job that is in great demand and will last in the future_

# %% [markdown]
# ### code to generate string in python

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# one step ..
#
# ___
#
# how to ..
#
# ***
#
# - number item
# - number item
#
# 1. number item
# 2. number item
#
# [Section title](#section-title)
